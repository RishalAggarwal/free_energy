# %%
import torch
import torch.distributions as D
import torch.nn as nn
import numpy as np

from matplotlib import pyplot as plt
from matplotlib import animation
import seaborn as sns

# %%
p0=D.Normal(0,1)
p1=D.Normal(0,2)

sample_p0=p0.sample((1000,))
sample_p1=p1.sample((1000,))
sample_p0=sample_p0.numpy()
sample_p1=sample_p1.numpy()

sns.distplot(sample_p0, label='p0')
sns.distplot(sample_p1, label='p1')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_374596/2445544741.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_p0, label='p0')
# /tmp/ipykernel_374596/2445544741.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_p1, label='p1')

# %%
#define neural network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1=nn.Linear(1, 100)
        self.fc2=nn.Linear(100, 100)
        self.fc3=nn.Linear(100, 1)
        self.partition=nn.Parameter(torch.tensor([1.], requires_grad=True))
    
    def forward(self, x):
        x=torch.relu(self.fc1(x))
        x=torch.relu(self.fc2(x))
        x=self.fc3(x)
        return - x - torch.log(self.partition)

# %%
#nce value function

def value(energy, noise, x, gen):
    logp_x = energy(x)  # logp(x)
    try:
        logq_x = noise.log_prob(x)  # logq(x)
    except:
        logq_x = noise.log_prob(x.clone().detach().cpu()).cuda()
    logp_gen = energy(gen)  # logp(x̃)
    try:
        logq_gen = noise.log_prob(gen)  # logq(x̃)
    except:
        logq_gen = noise.log_prob(gen.clone().detach().cpu()).cuda()
    value_data = logp_x - torch.logsumexp(torch.cat([logp_x, logq_x], dim=1), dim=1, keepdim=True)  # log[p(x)/(p(x) + q(x))]
    value_gen = logq_gen - torch.logsumexp(torch.cat([logp_gen, logq_gen], dim=1), dim=1, keepdim=True)  # log[q(x̃)/(p(x̃) + q(x̃))]

    v = value_data.mean() + value_gen.mean()

    r_x = torch.sigmoid(logp_x - logq_x)
    r_gen = torch.sigmoid(logq_gen - logp_gen)

    acc = ((r_x > 1/2).sum() + (r_gen > 1/2).sum()).cpu().numpy() / (len(x) + len(gen))

    return -v,  acc

# %%
#nce training 
def train(p0,p1):
    model=Net().cuda()
    optimizer=torch.optim.Adam(model.parameters(), lr=1e-5)
    training_iterations=10000
    batch_size=10000
    for i in range(training_iterations):
        optimizer.zero_grad()
        z=p1.sample((batch_size, 1)).cuda()
        loss, acc=value(model, p0, z, p0.sample((batch_size,1 )).cuda())
        loss.backward()
        optimizer.step()
        if i % 100 == 0:
            print('Iteration: %s, Loss: %s, Accuracy: %s' % (i, loss.item(), acc))
    return model
model=train(p0, p1)
# Out:
# Iteration: 0, Loss: 1.8503025770187378, Accuracy: 0.5
# Iteration: 100, Loss: 1.79220712184906, Accuracy: 0.5
# Iteration: 200, Loss: 1.724170207977295, Accuracy: 0.5
# Iteration: 300, Loss: 1.6485780477523804, Accuracy: 0.5
# Iteration: 400, Loss: 1.5902976989746094, Accuracy: 0.5
# Iteration: 500, Loss: 1.5279279947280884, Accuracy: 0.5
# Iteration: 600, Loss: 1.469894289970398, Accuracy: 0.5
# Iteration: 700, Loss: 1.4235951900482178, Accuracy: 0.5
# Iteration: 800, Loss: 1.3855916261672974, Accuracy: 0.5
# Iteration: 900, Loss: 1.3429851531982422, Accuracy: 0.5
# Iteration: 9700, Loss: 1.199446678161621, Accuracy: 0.66415
# Iteration: 9800, Loss: 1.199578046798706, Accuracy: 0.6633
# Iteration: 9900, Loss: 1.1998307704925537, Accuracy: 0.65875

# %%
print(model.partition.item())
# Out:
# 1.016038417816162

# %%
#plot model energy across x axis
x=np.linspace(-10, 10, 1000)
x=torch.Tensor(x).cuda().unsqueeze(1)
true_energy=p1.log_prob(x).detach().cpu().squeeze().numpy()
energy=model(x).detach().cpu().squeeze().numpy()
x=x.cpu().squeeze().numpy()
plt.plot(x, np.exp(energy),label='model_p1')
plt.plot(x, np.exp(true_energy), label='true_p1')
plt.legend()
plt.show()

# %% [markdown]
# #Unimodal to bimodal

# %%
def build_gmm(n_modes, means=None, vars=None):

    if means is None:
        means = torch.randn(n_modes,1)
    if vars is None:
        vars = torch.rand(n_modes,1)
        vars[:,1] = vars[:,0]

    mix = D.Categorical(torch.ones(n_modes,))
    comp = D.Independent(D.Normal(means, vars), 1)
    gmm = D.MixtureSameFamily(mix, comp)
    return gmm


p_0_means = torch.zeros(1)
p_0_vars = torch.ones(1)
p_0 = D.Normal(p_0_means, p_0_vars)


p_1_means = torch.tensor([[3], [ -3]]).float()
p_1_vars = torch.ones(2,1)*0.5
p_1 = build_gmm(2, p_1_means, p_1_vars)

x = torch.linspace(-6, 6, 1000).unsqueeze(1)
plt.plot(x, torch.exp(p_0.log_prob(x)), label='p_0')
plt.plot(x, torch.exp(p_1.log_prob(x)), label='p_1')
# plt.gca().set_aspect('equal', adjustable='box')
# xlim = plt.gca().get_xlim()
# ylim = plt.gca().get_ylim()
plt.legend()
plt.show()

# %%
model=train(p_0, p_1)
print(model.partition.item())
# Out:
# Iteration: 0, Loss: 1.7967603206634521, Accuracy: 0.5
# Iteration: 100, Loss: 1.7223995923995972, Accuracy: 0.5
# Iteration: 200, Loss: 1.6613216400146484, Accuracy: 0.5
# Iteration: 300, Loss: 1.5832459926605225, Accuracy: 0.5
# Iteration: 400, Loss: 1.5121911764144897, Accuracy: 0.5
# Iteration: 500, Loss: 1.4452838897705078, Accuracy: 0.5
# Iteration: 600, Loss: 1.3766900300979614, Accuracy: 0.5
# Iteration: 700, Loss: 1.3152185678482056, Accuracy: 0.5
# Iteration: 800, Loss: 1.2493976354599, Accuracy: 0.5
# Iteration: 900, Loss: 1.176522970199585, Accuracy: 0.5
# Iteration: 1000, Loss: 1.118747591972351, Accuracy: 0.5
# Iteration: 1100, Loss: 1.0660632848739624, Accuracy: 0.5
# Iteration: 1200, Loss: 1.0246217250823975, Accuracy: 0.60485
# Iteration: 1300, Loss: 0.9684858918190002, Accuracy: 0.66905
# Iteration: 1400, Loss: 0.9336013793945312, Accuracy: 0.7089
# Iteration: 1500, Loss: 0.8977780342102051, Accuracy: 0.7494
# Iteration: 1600, Loss: 0.8591397404670715, Accuracy: 0.79275
# Iteration: 1700, Loss: 0.8207611441612244, Accuracy: 0.8307
# Iteration: 1800, Loss: 0.7904798984527588, Accuracy: 0.85055
# Iteration: 1900, Loss: 0.7586967349052429, Accuracy: 0.8768
# Iteration: 6200, Loss: 0.24463100731372833, Accuracy: 0.96415
# Iteration: 6300, Loss: 0.23532894253730774, Accuracy: 0.96645
# Iteration: 6400, Loss: 0.23137927055358887, Accuracy: 0.9669
# Iteration: 6500, Loss: 0.2357134222984314, Accuracy: 0.96495
# Iteration: 6600, Loss: 0.22141602635383606, Accuracy: 0.96615
# Iteration: 6700, Loss: 0.22954711318016052, Accuracy: 0.9651
# Iteration: 6800, Loss: 0.22468464076519012, Accuracy: 0.967
# Iteration: 6900, Loss: 0.22958669066429138, Accuracy: 0.9637
# Iteration: 7000, Loss: 0.22328504920005798, Accuracy: 0.96445
# Iteration: 7100, Loss: 0.22099795937538147, Accuracy: 0.96555
# Iteration: 7200, Loss: 0.21017494797706604, Accuracy: 0.9666
# Iteration: 7300, Loss: 0.21050813794136047, Accuracy: 0.9671
# Iteration: 7400, Loss: 0.21078865230083466, Accuracy: 0.9681
# Iteration: 7500, Loss: 0.22083717584609985, Accuracy: 0.96635
# Iteration: 7600, Loss: 0.21182972192764282, Accuracy: 0.9657
# Iteration: 7700, Loss: 0.22253796458244324, Accuracy: 0.9637
# Iteration: 7800, Loss: 0.21140682697296143, Accuracy: 0.96495
# Iteration: 7900, Loss: 0.20979222655296326, Accuracy: 0.96625
# Iteration: 8000, Loss: 0.2153269350528717, Accuracy: 0.9646
# Iteration: 8100, Loss: 0.1963365077972412, Accuracy: 0.96775
# Iteration: 8200, Loss: 0.2091629058122635, Accuracy: 0.9647
# Iteration: 8300, Loss: 0.1989448070526123, Accuracy: 0.9672
# Iteration: 8400, Loss: 0.19756990671157837, Accuracy: 0.9663
# Iteration: 8500, Loss: 0.19938597083091736, Accuracy: 0.9662
# Iteration: 8600, Loss: 0.2090662717819214, Accuracy: 0.96415
# Iteration: 8700, Loss: 0.20348696410655975, Accuracy: 0.96525
# Iteration: 8800, Loss: 0.20089854300022125, Accuracy: 0.96535
# Iteration: 8900, Loss: 0.20050093531608582, Accuracy: 0.9658
# Iteration: 9000, Loss: 0.19823266565799713, Accuracy: 0.96465
# Iteration: 9100, Loss: 0.20259620249271393, Accuracy: 0.96695
# Iteration: 9200, Loss: 0.19722089171409607, Accuracy: 0.9671
# Iteration: 9300, Loss: 0.202945739030838, Accuracy: 0.9647
# Iteration: 9400, Loss: 0.19920112192630768, Accuracy: 0.96545
# Iteration: 9500, Loss: 0.19319400191307068, Accuracy: 0.96725
# Iteration: 9600, Loss: 0.19855183362960815, Accuracy: 0.96615
# Iteration: 9700, Loss: 0.1987130045890808, Accuracy: 0.96465
# Iteration: 9800, Loss: 0.20473253726959229, Accuracy: 0.9644
# Iteration: 9900, Loss: 0.2001907378435135, Accuracy: 0.96515
# 1.0428324937820435

# %%
x=np.linspace(-6, 6, 1000)
x=torch.Tensor(x).cuda().unsqueeze(1)
true_energy=p_1.log_prob(x.detach().cpu()).squeeze().numpy()
energy=model(x).detach().cpu().squeeze().numpy()
x=x.cpu().squeeze().numpy()
plt.plot(x, np.exp(energy),label='model_p1')
plt.plot(x, np.exp(true_energy), label='true_p1')
plt.legend()
